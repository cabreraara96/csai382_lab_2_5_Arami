-- %%
%sql
SELECT * FROM workspace.bronze.device_messages_raw LIMIT 10;

-- %%
%sql
SELECT * FROM workspace.bronze.rapid_step_tests_raw LIMIT 10;

-- %% [markdown]
-- ## Part 1: Exploring Raw STEDI Data
--
-- This section explores the raw parquet data imported into the bronze schema.
-- The goal is to understand structure, columns, and data quality before cleaning.

-- %%
%sql
DESCRIBE TABLE workspace.bronze.device_messages_raw;

-- %%
DESCRIBE TABLE workspace.bronze.rapid_step_tests_raw;

-- %% [markdown]
-- These queries show column names and data types so we can identify timestamps,
-- IDs, and fields that may require cleaning.

-- %%
SELECT * 
FROM workspace.bronze.device_messages_raw
LIMIT 20;

-- %%
SELECT *
FROM workspace.bronze.rapid_step_tests_raw
LIMIT 20;

-- %% [markdown]
-- Previewing the data helps identify null values, timestamp formats,
-- and potential join keys.
